# %% [markdown]
# ## Análise Exploratória em Python (Matplotlib)

# %%
import matplotlib.pyplot as plt

# pedir ajuda sobre a função
plt.plot?

# %%
# gráfico de linha simples

plt.plot([1,2,3,4])
plt.ylabel("Eixo y")
plt.xlabel("Eixo x")
# Out:
# Text(0.5, 0, 'Eixo x')

# %%
plt.plot([20, 30, 20, 40, 50])

# %%
plt.plot([10, 20, 30, 40], [100, 200, 300, 400])

# %%
plt.plot([10, 20, 30, 40], [100, 200, 300, 400], "x")

# pyplot marker

# %%
plt.plot([10, 20, 30, 40], [100, 200, 300, 400], "go-")
plt.ylabel("Eixo y")
plt.xlabel("Eixo x")
plt.title("Titulo do Grafico")
plt.axis([0, 50, 0, 900])
# Out:
# (0.0, 50.0, 0.0, 900.0)

# %%
plt.plot([10, 20, 30, 40], [100, 200, 300, 400], marker="o", color="red", linewidth=4)

plt.scatter([10, 20, 30, 40], [500, 600, 600, 700], color="blue")

plt.bar([10, 20, 30, 40], [90, 90, 70, 40], color="orange")
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Figures, Axes, Subplot

# %%
plt.figure(figsize=(10,2)) # (figsize=(largura,altura))

plt.plot([10,20,30,40])

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_axes([0.1, 0.1, 1, 0.4])

#Gerando amostra
import numpy as np
nu, sigma = 60, 10
x = nu + sigma * np.random.randn(500)

ax.hist(x, bins=40, facecolor="green", alpha=0.8) # alpha pode ser bom para marcar parte do gráfico
ax.set_xlabel("Score")
ax.set_ylabel("n")
ax.set_title("Histograma", fontsize=18)
ax.spines["right"].set_visible(False) # retira linha da direita
ax.spines["top"].set_visible(False) # retira linha de cima
ax.grid(True)

# %%
plt.hist(x, bins=50, facecolor="green", alpha=0.8);

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_axes([0.1, 0.1, 1, 0.4])

import numpy as np
nu, sigma = 60, 10
x = nu + sigma * np.random.randn(500)

ax.hist(x[x>=50], bins=50, facecolor="red", alpha=0.99);
ax.hist(x[x<50], bins=50, facecolor="red", alpha=0.35);

# %% [markdown]
# ## Outros gráficos

# %%
plt.bar(x=[1,2,3,4],height=[1,4,9,16], width=.75); # precisa de dois parametros

# %%
# vamos alterar o tamanho
fig = plt.figure(figsize=(8,6));

# é possível mudar algumas coisas inclusive parametros nao obrigatorios
plt.bar(x=[1,2,3,4],
        height=[1,4,9,16],
        color="r",
        width=.8,
        edgecolor="Black",
        tick_label=["Grupo A", "Grupo B", "Grupo C", "Grupo D"],
        bottom=5
        # log=True
        );

# e incrementar com o que já foi visto
plt.xlabel("Eixo X", fontsize=12);
plt.ylabel("Eixo Y", fontsize=12);
plt.title("Graf de Barras", fontsize=18, color="Black");

# %%
plt.barh([1,2,3,4],[1,4,9,16]);
plt.title("Graf. Horizontal")
# Out:
# Text(0.5, 1.0, 'Graf. Horizontal')

# %%
graf_bar = plt.bar([1,2,3,4],[1,4,9,16], tick_label=["Grupo A", "Grupo B", "Grupo C", "Grupo D"]);
graf_bar[0].set_color("red")
graf_bar[1].set_color("green")
graf_bar[2].set_color("orange")

# %%
import pandas as pd

housing = pd.read_csv("data\Housing.csv")
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
housing_median = plt.bar(x=housing.groupby("furnishingstatus")["bedrooms"].count().index, 
                         height=housing.groupby("furnishingstatus")["bedrooms"].count())

housing_median[0].set_color("red")
housing_median[1].set_color("orange")
housing_median[2].set_color("yellow")

plt.grid(True)

# %%
import seaborn as sns

sns.catplot(x="furnishingstatus", kind="count", data=housing);
# Out:
# C:\Users\Rafael\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.regplot(x="area", y="price", data=housing); # grafico de dispersao com regressao linear

# %%
iris = pd.read_csv("data\Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
plt.scatter(iris["SepalLengthCm"], iris["PetalLengthCm"]);
plt.title("Sepal x Petal Length", fontsize=12);

# %%
cores = {"Iris-setosa":"red", "Iris-versicolor":"blue", "Iris-virginica":"green"}

iris["Species"].apply(lambda x: cores[x]);

# %%
fig, ax = plt.subplots()

cores = {"Iris-setosa":"red", "Iris-versicolor":"blue", "Iris-virginica":"green"}

ax.scatter(iris["SepalLengthCm"], iris["PetalLengthCm"], c=iris["Species"].apply(lambda x: cores[x]));

plt.title("Sepal x Petal Length", fontsize=12)

plt.xlabel("SepalLengthCm", fontsize=6)
plt.ylabel("PetalLengthCm", fontsize=6)
# Out:
# Text(0, 0.5, 'PetalLengthCm')

# %%
plt.boxplot(iris["SepalLengthCm"]);

# %%
fifa19 = pd.read_csv("data\Revised-FIFA19.csv")

south_america = ["Brazil", "Argentina", "Peru", "Uruguay", "Chile", "Bolivia", "Colombia"]

fifa19_sa = fifa19[fifa19["Nationality"].isin(south_america)]
fifa19_not_sa = fifa19[fifa19["Nationality"].isin(south_america) == False]

sns.boxplot(x="Nationality", y="Age", data=fifa19_sa);

# Limite superior do boxplot: Q3 + 1.5*(Q3-Q1)
# Limite inferior do boxplot: Q3 - 1.5*(Q3-Q1)
# Interquartil: Q3-Q1

# %%
sns.boxplot(x="Species", y="PetalLengthCm", data=iris);

# %%
df = pd.read_csv("data\german_credit_data.csv")
plt.hist(df["Credit amount"], bins=50);

# %%
plt.boxplot(df["Credit amount"]);

# %%
nu, sigma = 60, 10
x = nu + sigma * np.random.randn(500)

plt.boxplot(x);
